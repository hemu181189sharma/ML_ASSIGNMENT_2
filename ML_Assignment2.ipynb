# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 147.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 132.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 62.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 155.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 144.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.8/289.8 MB 101.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python train_models.py
# Out:
# /home/cloud/anaconda3/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [00:43:39] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#                  Model  Accuracy       AUC  ...    Recall        F1       MCC
# 0       logistic_model  0.973684  0.997380  ...  0.985915  0.979021  0.943898
# 1  decision_tree_model  0.947368  0.943990  ...  0.957746  0.957746  0.887979
# 2            knn_model  0.947368  0.981985  ...  0.957746  0.957746  0.887979
# 3    naive_bayes_model  0.973684  0.998362  ...  1.000000  0.979310  0.944733
# 4  random_forest_model  0.964912  0.994759  ...  0.985915  0.972222  0.925285
# 5        xgboost_model  0.956140  0.990829  ...  0.971831  0.965035  0.906379
#
# [6 rows x 7 columns]
